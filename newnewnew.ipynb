Rk	 	Salary
1	Carmelo Anthony	$25,534,253
2	Kent Bazemore	$18,089,887
3	Jeremy Lin	$13,071,063
4	Miles Plumlee	$12,500,000
5	Dewayne Dedmon	$7,200,000
6	Trae Young	$5,356,440
7	Alex Len	$4,350,000
8	Taurean Waller-Prince	$2,526,840
9	Justin Anderson	$2,516,048
10	Vince Carter	$2,393,887
11	Jamal Crawford	$2,304,226
12	John Collins	$2,299,080
13	Kevin Huerter	$2,250,960
14	DeAndre' Bembry	$1,634,640
15	Omari Spellman	$1,620,480
16	Daniel Hamilton	$1,349,383
17	Jabari Bird	$1,349,383
18	Jaylen Adams	$236,854
19	Deyonta Davis	$196,553
20	Tyler Zeller	$106,974
21	B.J. Johnson	$94,742
22	Isaac Humphries	$47,371
23	Jordan Sibert	$47,371
24	Alex Poythress	$0*Atlanta Hawks*2018-19
"""

# %%
#https://www.basketball-reference.com/contracts/salary-cap-history.html

cap_history="""
Year	Salary Cap	Salary Cap (2019)
1984-85	$3,600,000	$8,557,797
1985-86	$4,233,000	$9,873,144
1986-87	$4,945,000	$11,128,422
1987-88	$6,164,000	$13,325,270
1988-89	$7,232,000	$14,916,364
1989-90	$9,802,000	$19,182,059
1990-91	$11,871,000	$22,283,140
1991-92	$12,500,000	$22,773,891
1992-93	$14,000,000	$24,778,161
1993-94	$15,175,000	$26,176,363
1994-95	$15,964,000	$26,785,632
1995-96	$23,000,000	$37,493,952
1996-97	$24,363,000	$38,802,016
1997-98	$26,900,000	$42,195,324
1998-99	$30,000,000	$46,042,748
1999-00	$34,000,000	$50,477,681
2000-01	$35,500,000	$51,258,504
2001-02	$42,500,000	$60,412,118
2002-03	$40,271,000	$55,969,987
2003-04	$43,840,000	$59,341,564
2004-05	$43,870,000	$57,429,410
2005-06	$49,500,000	$62,777,896
2006-07	$53,135,000	$65,516,964
2007-08	$55,630,000	$66,059,550
2008-09	$58,680,000	$69,929,958
2009-10	$57,700,000	$67,649,793
2010-11	$58,044,000	$65,969,238
2011-12	$58,044,000	$64,640,100
2012-13	$58,044,000	$63,707,436
2013-14	$58,679,000	$63,372,330
2014-15	$63,065,000	$68,023,079
2015-16	$70,000,000	$74,561,208
2016-17	$94,143,000	$98,194,497
2017-18	$99,093,000	$100,892,064
2018-19	$101,869,000	$101,869,000
2019-20	$109,140,000	
2020-21	$109,140,000	"""

empty=[]
cap_replace=cap_history.replace(",",'_').replace('$',"").replace('	', '*').replace('\n', '*')
cap_split=cap_replace.split('*')
for item in cap_split:
    if len(item)>3:
        empty.append(item)
cap = {empty[i]: float(empty[i + 1]) for i in range(3, len(empty)-4, 3)}
cap
# Out:
# {'1984-85': 3600000.0,
#  '1985-86': 4233000.0,
#  '1986-87': 4945000.0,
#  '1987-88': 6164000.0,
#  '1988-89': 7232000.0,
#  '1989-90': 9802000.0,
#  '1990-91': 11871000.0,
#  '1991-92': 12500000.0,
#  '1992-93': 14000000.0,
#  '1993-94': 15175000.0,
#  '1994-95': 15964000.0,
#  '1995-96': 23000000.0,
#  '1996-97': 24363000.0,
#  '1997-98': 26900000.0,
#  '1998-99': 30000000.0,
#  '1999-00': 34000000.0,
#  '2000-01': 35500000.0,
#  '2001-02': 42500000.0,
#  '2002-03': 40271000.0,
#  '2003-04': 43840000.0,
#  '2004-05': 43870000.0,
#  '2005-06': 49500000.0,
#  '2006-07': 53135000.0,
#  '2007-08': 55630000.0,
#  '2008-09': 58680000.0,
#  '2009-10': 57700000.0,
#  '2010-11': 58044000.0,
#  '2011-12': 58044000.0,
#  '2012-13': 58044000.0,
#  '2013-14': 58679000.0,
#  '2014-15': 63065000.0,
#  '2015-16': 70000000.0,
#  '2016-17': 94143000.0,
#  '2017-18': 99093000.0,
#  '2018-19': 101869000.0}

# %%
##player salaries


def player_salary(tbl):
    new=[]
    REPLACED=tbl.replace(",",'_').replace('$',"").replace('\n', '*').replace('	','*').replace('Salary','s')
    BROKEN=REPLACED.split('*')
    for item in BROKEN:
        if item=="0":
            item="0000"
        if len(item)>3:
            new.append(item)
    res_dict = {new[i]: new[i + 1] for i in range(0, len(new)-2, 2)}
    player_salary_df = pd.DataFrame.from_dict(res_dict, orient='index').reset_index().rename(columns={'index':'Player',0:'Salary'})
    player_salary_df['Season']= new[-1]
    player_salary_df['Team']= new[-2]
    player_salary_df.index+=1
    player_salary_df=player_salary_df.drop(columns=['Player'])
    player_salary_df[player_salary_df.columns[0]]=player_salary_df[player_salary_df.columns[0]].replace('_','', regex=True).astype(float)
    player_salary_df["% Total Salary"]= player_salary_df.Salary / player_salary_df.Salary.sum()*100
    player_salary_df["% Salary Cap"]= player_salary_df.Salary / cap[new[-1]] *100
    
    return player_salary_df

# %%
play=player_salary(atl)
play['Salary'].sum()
# Out:
# 107076435.0

# %%
play34=play.T.reset_index()

# %%
play34=play34.drop(columns='index')
play34
# Out:
#               1              2              3              4              5   \
# 0    2.55343e+07    1.80899e+07    1.30711e+07       1.25e+07        7.2e+06
# 1        2018-19        2018-19        2018-19        2018-19        2018-19
# 2  Atlanta Hawks  Atlanta Hawks  Atlanta Hawks  Atlanta Hawks  Atlanta Hawks
# 3        23.8468        16.8944        12.2072        11.6739        6.72417
# 4        25.0658         17.758        12.8312        12.2707         7.0679
#
#               6              7              8              9              10  \
# 0    5.35644e+06       4.35e+06    2.52684e+06    2.51605e+06    2.39389e+06
# 1        2018-19        2018-19        2018-19        2018-19        2018-19
# 2  Atlanta Hawks  Atlanta Hawks  Atlanta Hawks  Atlanta Hawks  Atlanta Hawks
# 3        5.00245        4.06252        2.35985        2.34977        2.23568
# 4        5.25816        4.27019        2.48048        2.46989        2.34997
#
# ...

# %%
play34
# Out:
#               1              2              3              4              5   \
# 0    2.55343e+07    1.80899e+07    1.30711e+07       1.25e+07        7.2e+06
# 1        2018-19        2018-19        2018-19        2018-19        2018-19
# 2  Atlanta Hawks  Atlanta Hawks  Atlanta Hawks  Atlanta Hawks  Atlanta Hawks
# 3        23.8468        16.8944        12.2072        11.6739        6.72417
# 4        25.0658         17.758        12.8312        12.2707         7.0679
#
#               6              7              8              9              10  \
# 0    5.35644e+06       4.35e+06    2.52684e+06    2.51605e+06    2.39389e+06
# 1        2018-19        2018-19        2018-19        2018-19        2018-19
# 2  Atlanta Hawks  Atlanta Hawks  Atlanta Hawks  Atlanta Hawks  Atlanta Hawks
# 3        5.00245        4.06252        2.35985        2.34977        2.23568
# 4        5.25816        4.27019        2.48048        2.46989        2.34997
#
# ...

# %%
data = [['Season','Team','Total Wins','Wins Reg','Wins PLayoffs','Salary','Cap','Sal_%_Cap','PS/G','PA/G','1P_%TS','1P_%SC','2P_%TS','2P_%SC','3P_%TS','3P_%SC','4P_%TS','4P_%SC','5P_%TS','5P_%SC','6P_%TS','6P_%SC','7P_%TS','7P_%SC','8P_%TS','8P_%SC','9P_%TS','9P_%SC','10P_%TS','10P_%SC'],
       ['2018-19','Atlanta Hawks',29,29,0,play['Salary'].sum(),cap['2018-19'],play['Salary'].sum()/cap['2018-19'],'NaN','NaN',tinyhawks[1:1],tinyhawks[2:1],tinyhawks[1:2],tinyhawks[2:2],tinyhawks[1:3],tinyhawks[2:3],tinyhawks[1:4],tinyhawks[2:4],tinyhawks[1:5],tinyhawks[2:5],tinyhawks[1:6],tinyhawks[2:6],tinyhawks[1:7],tinyhawks[2:7],tinyhawks[1:8],tinyhawks[2:8],tinyhawks[1:9],tinyhawks[2:9],tinyhawks[1:10],tinyhawks[2:10]]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-93e6fe8dc930> in <module>
#       1 data = [['Season','Team','Total Wins','Wins Reg','Wins PLayoffs','Salary','Cap','Sal_%_Cap','PS/G','PA/G','1P_%TS','1P_%SC','2P_%TS','2P_%SC','3P_%TS','3P_%SC','4P_%TS','4P_%SC','5P_%TS','5P_%SC','6P_%TS','6P_%SC','7P_%TS','7P_%SC','8P_%TS','8P_%SC','9P_%TS','9P_%SC','10P_%TS','10P_%SC'],
# ----> 2        ['2018-19','Atlanta Hawks',29,29,0,play['Salary'].sum(),cap['2018-19'],play['Salary'].sum()/cap['2018-19'],'NaN','NaN',tinyhawks[1:1],tinyhawks[2:1],tinyhawks[1:2],tinyhawks[2:2],tinyhawks[1:3],tinyhawks[2:3],tinyhawks[1:4],tinyhawks[2:4],tinyhawks[1:5],tinyhawks[2:5],tinyhawks[1:6],tinyhawks[2:6],tinyhawks[1:7],tinyhawks[2:7],tinyhawks[1:8],tinyhawks[2:8],tinyhawks[1:9],tinyhawks[2:9],tinyhawks[1:10],tinyhawks[2:10]]]
#
# NameError: name 'tinyhawks' is not defined

# %%
data

# %%
df

# %%
## team salaries


def shrink(list):
    new=[]
    test=list.replace(",",'_').replace('$',"").replace('\n', '.')
    test=test.split('.')
    for item in test:
        if len(item)>3:
            new.append(item)
    res_dict = {new[i]: new[i + 1] for i in range(0, len(new)-2, 2)}
    salary_df = pd.DataFrame.from_dict(res_dict, orient='index').reset_index().rename(columns={'index':'Team',0:'Salary'})
    salary_df['Season']= new[-1]
    return salary_df

# %%
LEAGUES=[league2009,league2010,league2011,league2012,league2013,league2014,league2015]

# %%
df2009=shrink(league2009)
df2010=shrink(league2010)
df2011=shrink(league2011)
df2012=shrink(league2012)
df2013=shrink(league2013)
df2014=shrink(league2014)
df2015=shrink(league2015)

# %%
table=pd.concat([df2009,df2010,df2011,df2012,df2013,df2014,df2015])
